# %%
import numpy as np

# %%
# %timeit np.random.normal(size=100_000_000)

# %%
# %timeit np.random.uniform(size=100_000_000)

# %%
from diffusionx import random

# %%
# %timeit random.uniform_rand(100_000_000)

# %%
# %timeit random.normal_rand(100_000_000)
