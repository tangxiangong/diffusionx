# %%
import numpy as np

# %%
# %timeit np.random.normal(size=100_000_000)
# Out:
# 3.28 s ± 91 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit np.random.uniform(size=100_000_000)
# Out:
# 1.15 s ± 8.11 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
